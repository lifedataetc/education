# %%
from support_funcs import *
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = get_yield_curves()

# %% [markdown]
# ## Pandas Visualization

# %%
df.index = df['date']

# %%
df['30_y'].hist()

# %%
df['30_y'].plot.hist(edgecolor='k').autoscale(enable=True, axis='both', tight=True)

# %%
df['30_y'].plot.hist(bins=40, edgecolor='k').autoscale(enable=True, axis='both', tight=True)

# %% [markdown]
# ## Line plots

# %%
df.plot.line(y=['30_y','1_m','1_y'],figsize=(18,9),lw=2,grid=True);

# %% [markdown]
# ## Area
